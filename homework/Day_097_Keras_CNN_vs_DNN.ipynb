# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
import os
# Out:
# /opt/intel/intelpython3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量

# 讀取資料並檢視
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## 首先我們使用一般的 DNN (MLP) 來訓練
# 由於 DNN 只能輸入一維的資料，我們要先將影像進行攤平，若 (50000, 32, 32, 3) 的影像，攤平後會變成 (50000, 32*32*3) = (50000, 3072)

# %%
# 將資料攤平成一維資料
x_train = x_train.reshape(50000, 3072) 
x_test = x_test.reshape(10000, 3072)

# 將資料變為 float32 並標準化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 93us/step - loss: 2.1639 - acc: 0.2466 - val_loss: 1.8197 - val_acc: 0.3513
# Epoch 2/10
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.8590 - acc: 0.3265 - val_loss: 1.8009 - val_acc: 0.3321
# Epoch 3/10
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.7833 - acc: 0.3575 - val_loss: 1.6762 - val_acc: 0.4060
# Epoch 4/10
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.7327 - acc: 0.3780 - val_loss: 1.7022 - val_acc: 0.3977
# Epoch 5/10
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.6959 - acc: 0.3896 - val_loss: 1.6314 - val_acc: 0.4194
# Epoch 6/10
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.6697 - acc: 0.3993 - val_loss: 1.6231 - val_acc: 0.4264
# Epoch 7/10
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.6483 - acc: 0.4088 - val_loss: 1.6370 - val_acc: 0.4051
# Epoch 8/10
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.6299 - acc: 0.4182 - val_loss: 1.5738 - val_acc: 0.4466
# Epoch 9/10
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.6143 - acc: 0.4241 - val_loss: 1.5522 - val_acc: 0.4561
# Epoch 10/10
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.6003 - acc: 0.4278 - val_loss: 1.5236 - val_acc: 0.4728
# Test loss: 1.5236255004882813
# Test accuracy: 0.4728

# %% [markdown]
# ## 接下來我們使用 CNN 來訓練神經網路
# CNN 的原理非常適合處理影像類的資料，就讓我們來看看，同樣的訓練條件，CNN 是否顯著優於 DNN 呢?

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.7666 - acc: 0.3592 - val_loss: 1.3987 - val_acc: 0.5000
# Epoch 2/10
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.3330 - acc: 0.5265 - val_loss: 1.1460 - val_acc: 0.5954
# Epoch 3/10
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.1267 - acc: 0.6023 - val_loss: 1.0026 - val_acc: 0.6478
# Epoch 4/10
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.9935 - acc: 0.6526 - val_loss: 0.9748 - val_acc: 0.6595
# Epoch 5/10
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.8920 - acc: 0.6898 - val_loss: 0.8119 - val_acc: 0.7186
# Epoch 6/10
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.8237 - acc: 0.7140 - val_loss: 0.7926 - val_acc: 0.7251
# Epoch 7/10
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.7667 - acc: 0.7316 - val_loss: 0.7685 - val_acc: 0.7384
# Epoch 8/10
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.7274 - acc: 0.7489 - val_loss: 0.9322 - val_acc: 0.6901
# Epoch 9/10
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.6910 - acc: 0.7588 - val_loss: 0.7872 - val_acc: 0.7317
# Epoch 10/10
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.6736 - acc: 0.7655 - val_loss: 0.7365 - val_acc: 0.7479
# Test loss: 0.7365292016983033
# Test accuracy: 0.7479

# %% [markdown]
# ## 同樣運算 10 個 epochs，但 CNN 在 test data 的準確率顯著優於 DNN!

# %% [markdown]
# ## 作業
# 1. 請試著調整各個超參數，並說明那些超參數對於結果有明顯的影響?
# 2. CNN 與 DNN 哪個模型的參數數量比較多? 造成參數的數量不同的原因在哪?
# Ans.DNN model的參數較多

# %%
# 調整Conv2D層數
'''
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量
'''
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
import os

def modPara(batchSize, epoch, filterNum, dropout, optimizer):
    batch_size = batchSize
    num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
    epochs = epoch
    
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    print('x_train shape:', x_train.shape)
    print(x_train.shape[0], 'train samples')
    print(x_test.shape[0], 'test samples')
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
    x_train /= 255
    x_test /= 255

    # Convert class vectors to binary class matrices.
    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)

    model = Sequential()
    model.add(Conv2D(32, (filterNum, filterNum), padding='same',
                     input_shape=x_train.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))

    model.add(Conv2D(64, (filterNum, filterNum), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(dropout))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))
    model.summary()
    
    if(optimizer=='RMSprop'):
        model.compile(loss='categorical_crossentropy',
                      optimizer=RMSprop(),
                      metrics=['accuracy'])
    else:
        model.compile(loss='categorical_crossentropy',
                      optimizer=Adam(),
                      metrics=['accuracy'])

    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=1,
                        validation_data=(x_test, y_test))
    score = model.evaluate(x_test, y_test, verbose=0)
    print('batchSize=',batchSize, ' epochs=',epoch,' filterNum=', filterNum,' dropout=', dropout, 'optimizer=',optimizer)
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])

# %%
#default比較組
modPara(128, 10, 3, 0.5, 'RMSprop')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# WARNING:tensorflow:From C:\Users\A60104\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\A60104\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.7702 - accuracy: 0.3605 - val_loss: 1.4034 - val_accuracy: 0.4797
# Epoch 2/10
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.4031 - accuracy: 0.4958 - val_loss: 1.1452 - val_accuracy: 0.5906
# Epoch 3/10
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.2527 - accuracy: 0.5558 - val_loss: 1.0401 - val_accuracy: 0.6336
# Epoch 4/10
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.1514 - accuracy: 0.5907 - val_loss: 1.0496 - val_accuracy: 0.6318
# Epoch 5/10
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.0856 - accuracy: 0.6168 - val_loss: 0.9709 - val_accuracy: 0.6584
# Epoch 6/10
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.0285 - accuracy: 0.6377 - val_loss: 0.9058 - val_accuracy: 0.6813
# Epoch 7/10
# 50000/50000 [==============================] - 85s 2ms/step - loss: 0.9859 - accuracy: 0.6548 - val_loss: 0.8827 - val_accuracy: 0.6937
# Epoch 8/10
# 50000/50000 [==============================] - 84s 2ms/step - loss: 0.9470 - accuracy: 0.6713 - val_loss: 1.0680 - val_accuracy: 0.6483
# Epoch 9/10
# 50000/50000 [==============================] - 85s 2ms/step - loss: 0.9206 - accuracy: 0.6802 - val_loss: 0.8277 - val_accuracy: 0.7134
# Epoch 10/10
# 50000/50000 [==============================] - 84s 2ms/step - loss: 0.9003 - accuracy: 0.6878 - val_loss: 0.8010 - val_accuracy: 0.7214
# batchSize= 128  epochs= 10  filterNum= 3  dropout= 0.5 optimizer= RMSprop
# Test loss: 0.800969179725647
# Test accuracy: 0.7214000225067139

# %%
#調整batchSize
modPara(32, 10, 3, 0.5, 'RMSprop')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_8 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_9 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_10 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_11 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_12 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 95s 2ms/step - loss: 1.6255 - accuracy: 0.4090 - val_loss: 1.2902 - val_accuracy: 0.5371
# Epoch 2/10
# 50000/50000 [==============================] - 95s 2ms/step - loss: 1.2996 - accuracy: 0.5374 - val_loss: 1.0675 - val_accuracy: 0.6221
# Epoch 3/10
# 50000/50000 [==============================] - 95s 2ms/step - loss: 1.2208 - accuracy: 0.5737 - val_loss: 1.2679 - val_accuracy: 0.5540
# Epoch 4/10
# 50000/50000 [==============================] - 94s 2ms/step - loss: 1.1816 - accuracy: 0.5926 - val_loss: 1.1535 - val_accuracy: 0.6168
# Epoch 5/10
# 50000/50000 [==============================] - 95s 2ms/step - loss: 1.1780 - accuracy: 0.6001 - val_loss: 1.6308 - val_accuracy: 0.5418
# Epoch 6/10
# 50000/50000 [==============================] - 95s 2ms/step - loss: 1.1820 - accuracy: 0.6015 - val_loss: 1.0700 - val_accuracy: 0.6595
# Epoch 7/10
# 50000/50000 [==============================] - 95s 2ms/step - loss: 1.2205 - accuracy: 0.5968 - val_loss: 1.0790 - val_accuracy: 0.6228
# Epoch 8/10
# 50000/50000 [==============================] - 96s 2ms/step - loss: 1.2497 - accuracy: 0.5885 - val_loss: 0.9581 - val_accuracy: 0.6650
# Epoch 9/10
# 50000/50000 [==============================] - 101s 2ms/step - loss: 1.2740 - accuracy: 0.5808 - val_loss: 1.1533 - val_accuracy: 0.6065
# Epoch 10/10
# 50000/50000 [==============================] - 99s 2ms/step - loss: 1.2990 - accuracy: 0.5743 - val_loss: 1.1689 - val_accuracy: 0.5958
# batchSize= 32  epochs= 10  filterNum= 3  dropout= 0.5 optimizer= RMSprop
# Test loss: 1.168944451713562
# Test accuracy: 0.59579998254776

# %%
#調整epoch
modPara(128, 50, 3, 0.5, 'RMSprop')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_13 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_14 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_15 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_16 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_17 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_18 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.8472 - accuracy: 0.3270 - val_loss: 1.5053 - val_accuracy: 0.4587
# Epoch 2/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.4299 - accuracy: 0.4904 - val_loss: 1.1953 - val_accuracy: 0.5650
# Epoch 3/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.2588 - accuracy: 0.5547 - val_loss: 1.0709 - val_accuracy: 0.6215
# Epoch 4/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.1472 - accuracy: 0.5932 - val_loss: 1.0226 - val_accuracy: 0.6375
# Epoch 5/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.0715 - accuracy: 0.6215 - val_loss: 0.9885 - val_accuracy: 0.6529
# Epoch 6/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.0088 - accuracy: 0.6464 - val_loss: 0.8524 - val_accuracy: 0.7007
# Epoch 7/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 0.9644 - accuracy: 0.6632 - val_loss: 0.8476 - val_accuracy: 0.7020
# Epoch 8/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 0.9290 - accuracy: 0.6736 - val_loss: 0.8386 - val_accuracy: 0.7119
# Epoch 9/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 0.9062 - accuracy: 0.6837 - val_loss: 0.7814 - val_accuracy: 0.7294
# Epoch 10/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 0.8822 - accuracy: 0.6944 - val_loss: 0.7735 - val_accuracy: 0.7299
# Epoch 11/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8658 - accuracy: 0.6989 - val_loss: 0.7921 - val_accuracy: 0.7287
# Epoch 12/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8471 - accuracy: 0.7079 - val_loss: 0.7577 - val_accuracy: 0.7413
# Epoch 13/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 0.8384 - accuracy: 0.7096 - val_loss: 0.8748 - val_accuracy: 0.7147
# Epoch 14/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 0.8277 - accuracy: 0.7144 - val_loss: 0.7714 - val_accuracy: 0.7334
# Epoch 15/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8166 - accuracy: 0.7180 - val_loss: 1.0355 - val_accuracy: 0.6871
# Epoch 16/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 0.8214 - accuracy: 0.7190 - val_loss: 0.7386 - val_accuracy: 0.7545
# Epoch 17/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 0.8174 - accuracy: 0.7196 - val_loss: 0.8108 - val_accuracy: 0.7239
# Epoch 18/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8142 - accuracy: 0.7250 - val_loss: 0.7200 - val_accuracy: 0.7557
# Epoch 19/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8078 - accuracy: 0.7283 - val_loss: 0.7796 - val_accuracy: 0.7501
# Epoch 20/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8058 - accuracy: 0.7267 - val_loss: 0.8600 - val_accuracy: 0.7250
# Epoch 21/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8116 - accuracy: 0.7259 - val_loss: 0.7137 - val_accuracy: 0.7582
# Epoch 22/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8104 - accuracy: 0.7258 - val_loss: 0.7765 - val_accuracy: 0.7442
# Epoch 23/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8063 - accuracy: 0.7296 - val_loss: 0.7569 - val_accuracy: 0.7459
# Epoch 24/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8043 - accuracy: 0.7296 - val_loss: 0.7325 - val_accuracy: 0.7523
# Epoch 25/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8124 - accuracy: 0.7281 - val_loss: 0.7799 - val_accuracy: 0.7436
# Epoch 26/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.7995 - accuracy: 0.7322 - val_loss: 0.6649 - val_accuracy: 0.7797
# Epoch 27/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 0.8034 - accuracy: 0.7305 - val_loss: 0.7639 - val_accuracy: 0.7514
# Epoch 28/50
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.8032 - accuracy: 0.7308 - val_loss: 0.7105 - val_accuracy: 0.7614
# Epoch 29/50
# 50000/50000 [==============================] - 88s 2ms/step - loss: 0.8063 - accuracy: 0.7303 - val_loss: 0.7170 - val_accuracy: 0.7642
# Epoch 30/50
# 50000/50000 [==============================] - 79s 2ms/step - loss: 0.8107 - accuracy: 0.7328 - val_loss: 0.8144 - val_accuracy: 0.7441
# Epoch 31/50
# 50000/50000 [==============================] - 79s 2ms/step - loss: 0.8079 - accuracy: 0.7287 - val_loss: 0.6986 - val_accuracy: 0.7634
# Epoch 32/50
# 50000/50000 [==============================] - 81s 2ms/step - loss: 0.8120 - accuracy: 0.7301 - val_loss: 0.6934 - val_accuracy: 0.7698
# Epoch 33/50
# 50000/50000 [==============================] - 80s 2ms/step - loss: 0.8194 - accuracy: 0.7278 - val_loss: 0.7664 - val_accuracy: 0.7510
# Epoch 34/50
# 50000/50000 [==============================] - 81s 2ms/step - loss: 0.8211 - accuracy: 0.7281 - val_loss: 0.9791 - val_accuracy: 0.6646
# Epoch 35/50
# 50000/50000 [==============================] - 81s 2ms/step - loss: 0.8235 - accuracy: 0.7237 - val_loss: 0.7239 - val_accuracy: 0.7549
# Epoch 36/50
# 50000/50000 [==============================] - 81s 2ms/step - loss: 0.8275 - accuracy: 0.7260 - val_loss: 0.7090 - val_accuracy: 0.7740
# Epoch 37/50
# 50000/50000 [==============================] - 80s 2ms/step - loss: 0.8281 - accuracy: 0.7262 - val_loss: 0.7089 - val_accuracy: 0.7570
# Epoch 38/50
# 50000/50000 [==============================] - 80s 2ms/step - loss: 0.8230 - accuracy: 0.7274 - val_loss: 0.8084 - val_accuracy: 0.7515
# Epoch 39/50
# 50000/50000 [==============================] - 80s 2ms/step - loss: 0.8374 - accuracy: 0.7229 - val_loss: 0.7161 - val_accuracy: 0.7697
# Epoch 40/50
# 50000/50000 [==============================] - 81s 2ms/step - loss: 0.8369 - accuracy: 0.7248 - val_loss: 0.6734 - val_accuracy: 0.7783
# Epoch 41/50
# 50000/50000 [==============================] - 81s 2ms/step - loss: 0.8282 - accuracy: 0.7285 - val_loss: 0.9266 - val_accuracy: 0.6912
# Epoch 42/50
# 50000/50000 [==============================] - 82s 2ms/step - loss: 0.8336 - accuracy: 0.7263 - val_loss: 0.9090 - val_accuracy: 0.6965
# Epoch 43/50
# 50000/50000 [==============================] - 82s 2ms/step - loss: 0.8461 - accuracy: 0.7217 - val_loss: 0.8953 - val_accuracy: 0.7125
# Epoch 44/50
# 50000/50000 [==============================] - 81s 2ms/step - loss: 0.8401 - accuracy: 0.7251 - val_loss: 0.7743 - val_accuracy: 0.7423
# Epoch 45/50
# 50000/50000 [==============================] - 81s 2ms/step - loss: 0.8461 - accuracy: 0.7231 - val_loss: 0.7264 - val_accuracy: 0.7580
# Epoch 46/50
# 50000/50000 [==============================] - 81s 2ms/step - loss: 0.8550 - accuracy: 0.7212 - val_loss: 0.7688 - val_accuracy: 0.7555
# Epoch 47/50
# 50000/50000 [==============================] - 80s 2ms/step - loss: 0.8536 - accuracy: 0.7208 - val_loss: 0.8819 - val_accuracy: 0.7109
# Epoch 48/50
# 50000/50000 [==============================] - 452s 9ms/step - loss: 0.8544 - accuracy: 0.7215 - val_loss: 0.8202 - val_accuracy: 0.7232
# Epoch 49/50
# 50000/50000 [==============================] - 516s 10ms/step - loss: 0.8633 - accuracy: 0.7174 - val_loss: 0.7040 - val_accuracy: 0.7692
# Epoch 50/50
# 50000/50000 [==============================] - 78s 2ms/step - loss: 0.8687 - accuracy: 0.7157 - val_loss: 0.6713 - val_accuracy: 0.7742
# batchSize= 128  epochs= 50  filterNum= 3  dropout= 0.5 optimizer= RMSprop
# Test loss: 0.6712995089530945
# Test accuracy: 0.7742000222206116

# %%
#調整optimizer
modPara(128, 10, 3, 0.5, 'Adam')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_19 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_20 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_21 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_22 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_23 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_24 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.7129 - accuracy: 0.3680 - val_loss: 1.3718 - val_accuracy: 0.5042
# Epoch 2/10
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.3434 - accuracy: 0.5160 - val_loss: 1.1530 - val_accuracy: 0.5870
# Epoch 3/10
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.2011 - accuracy: 0.5705 - val_loss: 1.0406 - val_accuracy: 0.6332
# Epoch 4/10
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1015 - accuracy: 0.6108 - val_loss: 0.9777 - val_accuracy: 0.6599
# Epoch 5/10
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.0281 - accuracy: 0.6377 - val_loss: 0.8929 - val_accuracy: 0.6872
# Epoch 6/10
# 50000/50000 [==============================] - 82s 2ms/step - loss: 0.9697 - accuracy: 0.6564 - val_loss: 0.8448 - val_accuracy: 0.7074
# Epoch 7/10
# 50000/50000 [==============================] - 82s 2ms/step - loss: 0.9212 - accuracy: 0.6744 - val_loss: 0.8170 - val_accuracy: 0.7169
# Epoch 8/10
# 50000/50000 [==============================] - 82s 2ms/step - loss: 0.8864 - accuracy: 0.6872 - val_loss: 0.7656 - val_accuracy: 0.7326
# Epoch 9/10
# 50000/50000 [==============================] - 82s 2ms/step - loss: 0.8613 - accuracy: 0.6959 - val_loss: 0.7611 - val_accuracy: 0.7351
# Epoch 10/10
# 50000/50000 [==============================] - 82s 2ms/step - loss: 0.8360 - accuracy: 0.7064 - val_loss: 0.7763 - val_accuracy: 0.7292
# batchSize= 128  epochs= 10  filterNum= 3  dropout= 0.5 optimizer= Adam
# Test loss: 0.7762510875701905
# Test accuracy: 0.729200005531311

# %%
#調整dropout
modPara(128, 10, 3, 0.25, 'RMSprop')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_25 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_26 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_27 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_28 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_29 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_30 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 74s 1ms/step - loss: 1.7241 - accuracy: 0.3803 - val_loss: 1.3367 - val_accuracy: 0.5282
# Epoch 2/10
# 50000/50000 [==============================] - 75s 1ms/step - loss: 1.2547 - accuracy: 0.5545 - val_loss: 1.0450 - val_accuracy: 0.6257
# Epoch 3/10
# 50000/50000 [==============================] - 74s 1ms/step - loss: 1.0332 - accuracy: 0.6364 - val_loss: 0.9892 - val_accuracy: 0.6535
# Epoch 4/10
# 50000/50000 [==============================] - 74s 1ms/step - loss: 0.8998 - accuracy: 0.6834 - val_loss: 0.9734 - val_accuracy: 0.6615
# Epoch 5/10
# 50000/50000 [==============================] - 74s 1ms/step - loss: 0.7980 - accuracy: 0.7213 - val_loss: 0.8328 - val_accuracy: 0.7131
# Epoch 6/10
# 50000/50000 [==============================] - 74s 1ms/step - loss: 0.7192 - accuracy: 0.7517 - val_loss: 0.8028 - val_accuracy: 0.7223
# Epoch 7/10
# 50000/50000 [==============================] - 75s 1ms/step - loss: 0.6611 - accuracy: 0.7707 - val_loss: 0.7063 - val_accuracy: 0.7553
# Epoch 8/10
# 50000/50000 [==============================] - 74s 1ms/step - loss: 0.6145 - accuracy: 0.7863 - val_loss: 0.7033 - val_accuracy: 0.7692
# Epoch 9/10
# 50000/50000 [==============================] - 75s 1ms/step - loss: 0.5651 - accuracy: 0.8039 - val_loss: 0.6711 - val_accuracy: 0.7749
# Epoch 10/10
# 50000/50000 [==============================] - 74s 1ms/step - loss: 0.5308 - accuracy: 0.8162 - val_loss: 0.6455 - val_accuracy: 0.7838
# batchSize= 128  epochs= 10  filterNum= 3  dropout= 0.25 optimizer= RMSprop
# Test loss: 0.6454913827419281
# Test accuracy: 0.7838000059127808

# %%
#調整Conv2D層數
batch_size = 128
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

#多一組conv2D+conv2D
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()


model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
#print('batchSize=',batchSize, ' epochs=',epoch,' filterNum=', filterNum,' dropout=', dropout, 'optimizer=',optimizer')
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_29 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_38 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_39 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_40 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_41 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 6, 6, 64)          36928
# _________________________________________________________________
# activation_42 (Activation)   (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 4, 4, 64)          36928
# _________________________________________________________________
# activation_43 (Activation)   (None, 4, 4, 64)          0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               131584
# _________________________________________________________________
# activation_44 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_45 (Activation)   (None, 10)                0
# =================================================================
# Total params: 276,138
# Trainable params: 276,138
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 74s 1ms/step - loss: 1.9957 - accuracy: 0.2562 - val_loss: 1.6442 - val_accuracy: 0.3907
# Epoch 2/10
# 50000/50000 [==============================] - 78s 2ms/step - loss: 1.6523 - accuracy: 0.3942 - val_loss: 1.3995 - val_accuracy: 0.4900
# Epoch 3/10
# 50000/50000 [==============================] - 79s 2ms/step - loss: 1.4798 - accuracy: 0.4611 - val_loss: 1.2665 - val_accuracy: 0.5408
# Epoch 4/10
# 50000/50000 [==============================] - 79s 2ms/step - loss: 1.3576 - accuracy: 0.5095 - val_loss: 1.3313 - val_accuracy: 0.5210
# Epoch 5/10
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.2734 - accuracy: 0.5437 - val_loss: 1.1182 - val_accuracy: 0.5948
# Epoch 6/10
# 50000/50000 [==============================] - 79s 2ms/step - loss: 1.2205 - accuracy: 0.5644 - val_loss: 1.0521 - val_accuracy: 0.6293
# Epoch 7/10
# 50000/50000 [==============================] - 79s 2ms/step - loss: 1.1685 - accuracy: 0.5851 - val_loss: 1.0630 - val_accuracy: 0.6310
# Epoch 8/10
# 50000/50000 [==============================] - 79s 2ms/step - loss: 1.1209 - accuracy: 0.6031 - val_loss: 1.2228 - val_accuracy: 0.5851
# Epoch 9/10
# 50000/50000 [==============================] - 79s 2ms/step - loss: 1.0826 - accuracy: 0.6201 - val_loss: 0.9569 - val_accuracy: 0.6644
# Epoch 10/10
# 50000/50000 [==============================] - 79s 2ms/step - loss: 1.0598 - accuracy: 0.6300 - val_loss: 1.0066 - val_accuracy: 0.6438
# Test loss: 1.0065600448608398
# Test accuracy: 0.6438000202178955
